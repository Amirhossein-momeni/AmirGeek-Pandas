# %%
import pandas as pd
df = pd.read_csv(r'../Pandas/000 DATA/Cancer.csv')

# %%
df.head()
# head() is used to get the first 5 rows of the dataset
# If you want to other number of rows you can use df.head(10) or df.head(20) or another number

# %%
df.tail()
# tail() is used to get the last 5 rows of the dataset
# If you want to other number of rows you can use df.tail(10) or df.tail(20) or another number

# %%
df.shape 
# shape is used to get the number of rows and columns of the dataset
