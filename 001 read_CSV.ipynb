# %%
import pandas as pd

# %%
df = pd.read_csv('Your link to the CSV file')
print(df)

# You can also insert r before the link to avoid errors with backslashes in the path:
# df = pd.read_csv(r'Your link to the CSV file')

# Your data name is : DateFrame so you can use df to call it

# For create a CSV file from exel file you should go to exel file then save as and choose CSV file type
